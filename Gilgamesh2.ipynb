# %%
from __future__ import division

import os

import numpy as np

from glob import glob

import reduce_dblspec

import astropy

from astropy.io import fits
from astropy import units as u
from astropy.table import Table

from astropy import modeling
from astropy.modeling import models, fitting

from astropy import constants as cnst
# %matplotlib inline
from matplotlib import pyplot as plt
import pipeline
from photutils import centroid_com
from astropy import units as u
from astropy import constants as const
import pandas as pd
import math as m
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp
from astropy import constants as const
from astropy.stats import sigma_clip
from astropy.modeling.models import custom_model
from astropy.modeling.fitting import LevMarLSQFitter


from astropy.visualization import quantity_support
quantity_support() #not sure about this line but stackoverflow...try w/o it later

from matplotlib import pyplot as plt

# %%
from __future__ import division

import os

import numpy as np

from glob import glob

import reduce_dblspec

import astropy

from astropy.io import fits
from astropy import units as u
from astropy.table import Table

from astropy import modeling
from astropy.modeling import models, fitting

from astropy import constants as cnst
# %matplotlib inline
from matplotlib import pyplot as plt
import pipeline
from photutils import centroid_com
from astropy import units as u
from astropy import constants as const
import pandas as pd
import math as m
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp
from astropy import constants as const
from astropy.stats import sigma_clip
from astropy.modeling.models import custom_model
from astropy.modeling.fitting import LevMarLSQFitter


from astropy.visualization import quantity_support
quantity_support() #not sure about this line but stackoverflow...try w/o it later

from matplotlib import pyplot as plt

# %%
#Finding all data file for specific target and doing instrumentation noise subtraction
flatid = 'DomeFlat'
atlasfiles_red = fits.open('henear.fits') #NOAO atlas  #RED side 
atlasfiles_blue = fits.open('fear.fits') #NOAO atlas #BLUE side 
linelist_red = reduce_dblspec.HENEAR_LINE_LIST #RED side
linelist_blue = reduce_dblspec.FEAR_LINE_LIST #BLUE side

############### possible changes to change targets
##################################################
arcfiles_red10 = 'DoubleSpec/20170518/red0012.fits' #ARC lamp #1.0" slit #RED side
arcfiles_blue10 = 'DoubleSpec/20170518/blue0012.fits' #ARC lamp #1.0" slit #BLUE side
targetID = '65566078402826-Gilgamesh'
all_side_files_red = 'DoubleSpec/20170518/red*.fits'#RED side
all_side_files_blue = 'DoubleSpec/20170518/blue*.fits'#BLUE side
#target = fits.open('DoubleSpec/20170518/red0088.fits') #use these to get targetid
target[0].header
##################################################
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4141 / length of data axis 1
# NAXIS2  =                  440 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format defined in Astronomy and
# COMMENT   Astrophysics Supplement Series v44/p363, v44/p371, v73/p359, v73/p365.
# COMMENT   Contact the NASA Science Office of Standards and Technology for the
# COMMENT   FITS Definition document #100 and other FITS information.
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# OBJECT  = '65566078402826-Gilgamesh' / object title
# OBSERVER= 'Tollerud/Warrener'  / observer
# IMGTYPE = 'object  '           / observation type
# GAIN    =                  2.8 / e-/adu
# RON     =                  8.5 / system noise e-
# DICHROIC= 'D55     '           / Dichroic
# APERTURE= '1.0     '           / aperture (arcsecs)
# TURRET  = 'APERTURE'           / turret position
# LAMPS   = '0000000 '           / lamps: D-FeAr-Hg-Ar-Ne-He-InCand
# RFILTER = 'OPEN    '           /  filter wheel
# OEXPTIME=                 600. / originaly req. exposure time
# EXPTIME =                 600. / actual exposure time
# UTSHUT  = '2017-05-18T10:08:44.396' / UT shutter open
# DATE    = '2017-05-18T10:19:07' / file creation date (YYYY-MM-DDThh:mm:ss UTC)
# NAMPSXY = '1 1     '           / number of amplifiers in y x
# CCDSUM  = '1 1     '           / binning in x y
# ASEC1   = '[1:4141,1:440]'     / amplifier section 1(LL)
# BSEC1   = '[4122:4141,1:440]'  / bias section 1(LL)
# CSEC1   = '[1:4121,1:440]'     / ccd section 1(LL)
# DSEC1   = '[1:4121,1:440]'     / data section 1(LL)
# TSEC1   = '[8:4121,1:440]'     / trim section 1(LL)
# ROISEC  = '[1:4114,785:1224]'  / roi section
# DETID   = 'LBNL_4Kx2K_1'       / detector ID
# DETNUM  = '1       '           / Detector Number
# DETNAM  = 'LBNL_4Kx2K'         / detector name
# FPA     = 'DBSP_RED2'          / focal plan array
# UTC     = '138 10:08:44.4'     / <elapsed days> <time-obs>
# UT      = '10:08:44.4'         / time-obs
# OBSLST  = '18:06:25.7'         / lst-obs
# RA      = '15:35:08.38'        / Right Ascencion
# DEC     = '+16:52:27.6'        / Declination
# HOURANG = 'W02:30:28.9'        / Hour angle, TCS format
# HA      = '+02:30:28.9'        / Hour angle
# AIRMASS = '1.261   '           / Airmass
# TELID   = '200     '           / telescope ID
# TELFOCUS= '41.64 mm'           / focus position
# CASSPA  = '-30.10  '           / cass ring angle
# PARALLAC= '56.58   '           / parallactic angle
# DHE     = 'SDSU Gen III'       / controller info
# CCDTEMP = '130.003 '           / detector mount temp
# SOFTVER = '3.4     '           / software version
# HDR_REV = '4.3     '           / gfits version
# GCOMMENT= '        '           / comment
# ANGLE   = '24 deg 38 min'      / Grating Angle
# GRATING = '316/7500'           / lines/mm & Blaze
# CRVAL1  =            48.519459
# CRVAL2  =            33.313332

# %%
#find host z to estimate ha location to verify that emission seen in 2d is ha

# %%
#creating a ds _ part one

#plotting arc lamp pixel data and atlas wl data to match lines in next cell
specset_red = pipeline.dispersion(all_side_files_red, atlasfiles_red, arcfiles_red10, linelist_red,flatid)
# Out:
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:256: RuntimeWarning: invalid value encountered in sqrt
#   unc = (result/self.header['GAIN'] + self.unc[tsl]**2)**0.5
# used atlas plot limits for Red side

# %%
#creating a ds _ part one

#plotting arc lamp pixel data and atlas wl data to match lines in next cell
specset_red = pipeline.dispersion(all_side_files_red, atlasfiles_red, arcfiles_red10, linelist_red,flatid)
# Out:
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:256: RuntimeWarning: invalid value encountered in sqrt
#   unc = (result/self.header['GAIN'] + self.unc[tsl]**2)**0.5
# used atlas plot limits for Red side

# %%
#creating a ds _ part two

#use above plots to enter guesses of matching lines
pipeline.guess_plot(3370,9657,specset_red) #(arc-PIX-guess, atlas-WL-from-linelist)

#collect guesses here ~5 seems good
pixel_guesses = [3024,2373,2062,1672,3370]
atlas_lines = [9122.9674,8115.311,7635.106,7032.4131,9657.7863]
guesses = list(zip(pixel_guesses, atlas_lines)) #must be tuples

# %%
#creating a ds _ part three

ds_red = pipeline.goodness_of_matches(arcfiles_red10, guesses, all_side_files_red, atlasfiles_red, linelist_red, flatid);
#this is the final red side ds
# Out:
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:256: RuntimeWarning: invalid value encountered in sqrt
#   unc = (result/self.header['GAIN'] + self.unc[tsl]**2)**0.5
# chose ds for redside
# chose guesses for redside
# Skipping line HeI at wl=3187.745 - out of wl min/max
# Skipping line ArII at wl=3307.2283 - out of wl min/max
# Skipping line ArI at wl=3319.3446 - out of wl min/max
# Skipping line ArII at wl=3350.9243 - out of wl min/max
# Skipping line HeI at wl=3354.55 - out of wl min/max
# Skipping line ArI at wl=3373.4823 - out of wl min/max
# Skipping line ArII at wl=3376.4359 - out of wl min/max
# Skipping line ArII at wl=3388.5309 - out of wl min/max
# Skipping line NeII at wl=3397.866 - out of wl min/max
# Skipping line ArI at wl=3406.1804 - out of wl min/max
# Skipping line ArII at wl=3414.4583 - out of wl min/max
# Skipping line NeI at wl=3417.9035 - out of wl min/max
# Skipping line ArII at wl=3421.6107 - out of wl min/max
# Skipping line ArII at wl=3454.0952 - out of wl min/max
# Skipping line ArII at wl=3464.1272 - out of wl min/max
# Skipping line NeI at wl=3472.5711 - out of wl min/max
# Skipping line ArII at wl=3476.7474 - out of wl min/max
# Skipping line ArII at wl=3480.5055 - out of wl min/max
# Skipping line ArII at wl=3509.7785 - out of wl min/max
# Skipping line ArII at wl=3514.3877 - out of wl min/max
# Skipping line ArII at wl=3535.3196 - out of wl min/max
# Skipping line ArII at wl=3548.5144 - out of wl min/max
# Skipping line ArI at wl=3554.3058 - out of wl min/max
# Skipping line ArII at wl=3559.5081 - out of wl min/max
# Skipping line ArII at wl=3561.0304 - out of wl min/max
# Skipping line ArI at wl=3567.6564 - out of wl min/max
# Skipping line ArI at wl=3572.296 - out of wl min/max
# Skipping line ArII at wl=3576.6156 - out of wl min/max
# Skipping line ArII at wl=3588.4407 - out of wl min/max
# Skipping line NeI at wl=3600.1691 - out of wl min/max
# Skipping line ArI at wl=3606.5218 - out of wl min/max
# Skipping line HeI at wl=3613.643 - out of wl min/max
# Skipping line ArII at wl=3622.1375 - out of wl min/max
# Skipping line ArII at wl=3637.031 - out of wl min/max
# Skipping line ArII at wl=3639.8329 - out of wl min/max
# Skipping line ArI at wl=3643.1169 - out of wl min/max
# Skipping line ArII at wl=3655.2782 - out of wl min/max
# Skipping line ArI at wl=3690.8951 - out of wl min/max
# Skipping line ArII at wl=3718.2065 - out of wl min/max
# Skipping line ArII at wl=3720.4265 - out of wl min/max
# Skipping line ArII at wl=3724.5165 - out of wl min/max
# Skipping line ArII at wl=3729.3087 - out of wl min/max
# Skipping line ArII at wl=3737.889 - out of wl min/max
# Skipping line ArII at wl=3780.8398 - out of wl min/max
# Skipping line ArII at wl=3786.3824 - out of wl min/max
# Skipping line ArII at wl=3796.5934 - out of wl min/max
# Skipping line ArII at wl=3799.382 - out of wl min/max
# Skipping line ArII at wl=3803.1724 - out of wl min/max
# Skipping line ArII at wl=3809.4561 - out of wl min/max
# Skipping line HeI at wl=3819.6072 - out of wl min/max
# Skipping line ArI at wl=3834.6787 - out of wl min/max
# Skipping line ArII at wl=3850.5813 - out of wl min/max
# Skipping line ArII at wl=3868.5284 - out of wl min/max
# Skipping line ArII at wl=3875.2645 - out of wl min/max
# Skipping line HeI at wl=3888.648 - out of wl min/max
# Skipping line ArII at wl=3914.7675 - out of wl min/max
# Skipping line ArII at wl=3925.7188 - out of wl min/max
# Skipping line ArII at wl=3928.6233 - out of wl min/max
# Skipping line ArII at wl=3932.5466 - out of wl min/max
# Skipping line ArII at wl=3946.0971 - out of wl min/max
# Skipping line ArI at wl=3947.5046 - out of wl min/max
# Skipping line ArI at wl=3948.9789 - out of wl min/max
# Skipping line HeI at wl=3964.7289 - out of wl min/max
# Skipping line ArII at wl=3968.3594 - out of wl min/max
# Skipping line ArII at wl=3974.4766 - out of wl min/max
# Skipping line ArII at wl=3979.3559 - out of wl min/max
# Skipping line ArII at wl=3994.7918 - out of wl min/max
# Skipping line HeI at wl=4009.268 - out of wl min/max
# Skipping line ArII at wl=4013.8566 - out of wl min/max
# Skipping line ArII at wl=4033.8093 - out of wl min/max
# Skipping line ArII at wl=4035.46 - out of wl min/max
# Skipping line ArI at wl=4044.4179 - out of wl min/max
# Skipping line ArII at wl=4052.9208 - out of wl min/max
# Skipping line ArI at wl=4054.5258 - out of wl min/max
# Skipping line ArII at wl=4082.3872 - out of wl min/max
# Skipping line ArII at wl=4103.9121 - out of wl min/max
# Skipping line ArII at wl=4112.8153 - out of wl min/max
# Skipping line HeI at wl=4120.815 - out of wl min/max
# Skipping line ArII at wl=4131.7235 - out of wl min/max
# Skipping line ArII at wl=4156.086 - out of wl min/max
# Skipping line ArI at wl=4158.5907 - out of wl min/max
# Skipping line ArI at wl=4164.1795 - out of wl min/max
# Skipping line HeI at wl=4168.967 - out of wl min/max
# Skipping line ArI at wl=4181.8836 - out of wl min/max
# Skipping line ArI at wl=4198.317 - out of wl min/max
# Skipping line ArI at wl=4200.6745 - out of wl min/max
# Skipping line ArII at wl=4222.6373 - out of wl min/max
# Skipping line ArII at wl=4237.2198 - out of wl min/max
# Skipping line ArI at wl=4251.1846 - out of wl min/max
# Skipping line ArI at wl=4259.3619 - out of wl min/max
# Skipping line ArI at wl=4272.1689 - out of wl min/max
# Skipping line ArII at wl=4277.5282 - out of wl min/max
# Skipping line ArII at wl=4282.8976 - out of wl min/max
# Skipping line ArI at wl=4300.1008 - out of wl min/max
# Skipping line ArII at wl=4331.1995 - out of wl min/max
# Skipping line ArI at wl=4333.5612 - out of wl min/max
# Skipping line ArI at wl=4335.3379 - out of wl min/max
# Skipping line ArI at wl=4345.168 - out of wl min/max
# Skipping line ArII at wl=4348.064 - out of wl min/max
# Skipping line ArII at wl=4352.2049 - out of wl min/max
# Skipping line ArII at wl=4367.8316 - out of wl min/max
# Skipping line ArII at wl=4379.6668 - out of wl min/max
# Skipping line ArII at wl=4426.0011 - out of wl min/max
# Skipping line ArII at wl=4430.189 - out of wl min/max
# Skipping line HeI at wl=4437.551 - out of wl min/max
# Skipping line ArII at wl=4448.8792 - out of wl min/max
# Skipping line KrI at wl=4453.9177 - out of wl min/max
# Skipping line KrI at wl=4463.6901 - out of wl min/max
# Skipping line HeI at wl=4471.479 - out of wl min/max
# Skipping line ArII at wl=4474.7594 - out of wl min/max
# Skipping line ArII at wl=4481.8107 - out of wl min/max
# Skipping line ArII at wl=4490.9816 - out of wl min/max
# Skipping line ArII at wl=4498.5384 - out of wl min/max
# Skipping line KrI at wl=4502.3546 - out of wl min/max
# Skipping line ArI at wl=4510.7332 - out of wl min/max
# Skipping line ArI at wl=4522.323 - out of wl min/max
# Skipping line ArII at wl=4530.5523 - out of wl min/max
# Skipping line ArII at wl=4535.4903 - out of wl min/max
# Skipping line ArII at wl=4537.6426 - out of wl min/max
# Skipping line ArII at wl=4545.0519 - out of wl min/max
# Skipping line ArII at wl=4579.3495 - out of wl min/max
# Skipping line ArII at wl=4589.8978 - out of wl min/max
# Skipping line ArI at wl=4596.0967 - out of wl min/max
# Skipping line ArII at wl=4598.7627 - out of wl min/max
# Skipping line ArII at wl=4609.5673 - out of wl min/max
# Skipping line ArI at wl=4628.4409 - out of wl min/max
# Skipping line ArII at wl=4637.2328 - out of wl min/max
# Skipping line ArII at wl=4657.9012 - out of wl min/max
# Skipping line ArI at wl=4702.3161 - out of wl min/max
# Skipping line HeI at wl=4713.1455 - out of wl min/max
# Skipping line ArII at wl=4721.591 - out of wl min/max
# Skipping line ArII at wl=4726.8683 - out of wl min/max
# Skipping line ArII at wl=4735.9058 - out of wl min/max
# Skipping line ArII at wl=4764.8646 - out of wl min/max
# Skipping line ArI at wl=4768.675 - out of wl min/max
# Skipping line ArII at wl=4806.0205 - out of wl min/max
# Skipping line ArII at wl=4847.8095 - out of wl min/max
# Skipping line ArII at wl=4865.91 - out of wl min/max
# Skipping line ArI at wl=4876.2611 - out of wl min/max
# Skipping line ArII at wl=4879.8635 - out of wl min/max
# Skipping line ArI at wl=4894.6909 - out of wl min/max
# Skipping line ArII at wl=4904.7516 - out of wl min/max
# Skipping line HeI at wl=4921.931 - out of wl min/max
# Skipping line ArII at wl=4933.2091 - out of wl min/max
# Skipping line ArII at wl=4965.0795 - out of wl min/max
# Skipping line ArII at wl=4972.1597 - out of wl min/max
# Skipping line ArII at wl=5009.3344 - out of wl min/max
# Skipping line HeI at wl=5015.6779 - out of wl min/max
# Skipping line HeI at wl=5047.738 - out of wl min/max
# Skipping line ArII at wl=5062.0371 - out of wl min/max
# Skipping line ArII at wl=5141.7827 - out of wl min/max
# Skipping line ArII at wl=5145.3083 - out of wl min/max
# Skipping line ArI at wl=5151.3907 - out of wl min/max
# Skipping line ArI at wl=5162.2846 - out of wl min/max
# Skipping line ArI at wl=5187.7462 - out of wl min/max
# Skipping line ArI at wl=5221.271 - out of wl min/max
# Skipping line ArI at wl=5252.788 - out of wl min/max
# Skipping line NeI at wl=5330.7775 - out of wl min/max
# Skipping line ArI at wl=5373.4943 - out of wl min/max
# Skipping line ArI at wl=5393.9719 - out of wl min/max
# Skipping line NeI at wl=5400.5617 - out of wl min/max
# Skipping line ArI at wl=5410.473 - out of wl min/max
# Skipping line ArI at wl=5421.3517 - out of wl min/max
# Skipping line ArI at wl=5451.652 - out of wl min/max
# Skipping line ArI at wl=5467.1704 - out of wl min/max
# Skipping line ArI at wl=5473.4516 - out of wl min/max
# Skipping line ArI at wl=5495.8738 - out of wl min/max
# Skipping line ArI at wl=5506.1128 - out of wl min/max
# Skipping line ArI at wl=5524.957 - out of wl min/max
# Skipping line ArI at wl=5588.72 - out of wl min/max
# Skipping line ArI at wl=5597.4756 - out of wl min/max
# Failed to find line ArI at wl=5606.733: "Guessed line's peak to base ratio is 1.2379853302450323, which is less than 10"
# Failed to find line ArI at wl=5681.9001: "Guessed line's peak to base ratio is 0.7488019740383794, which is less than 10"
# Failed to find line NeI at wl=5689.8163: "Guessed line's peak to base ratio is 1.0412866213643168, which is less than 10"
# Failed to find line ArI at wl=5700.873: "Guessed line's peak to base ratio is 1.0353452239000849, which is less than 10"
# Failed to find line ArI at wl=5739.5196: "Guessed line's peak to base ratio is 1.1147845787558688, which is less than 10"
# Failed to find line NeI at wl=5748.2985: "Tried to find peak at 832.4684107331597 but it's in a valley, not a peak"
# Failed to find line NeI at wl=5764.4188: "Guessed line's peak to base ratio is 1.255886900497932, which is less than 10"
# Failed to find line ArI at wl=5772.1143: "Guessed line's peak to base ratio is 2.631675126187176, which is less than 10"
# Failed to find line ArI at wl=5783.536: "Guessed line's peak to base ratio is 0.8883406162696149, which is less than 10"
# Failed to find line NeI at wl=5820.1558: "Tried to find peak at 879.7450454610649 but it's in a valley, not a peak"
# Failed to find line NeI at wl=5852.4878: "Guessed line's peak to base ratio is 3.888374766328927, which is less than 10"
# Failed to find line HeI at wl=5875.621: "Guessed line's peak to base ratio is 5.273934410155609, which is less than 10"
# Failed to find line NeI at wl=5881.895: "Tried to find peak at 920.3328435838281 but it's in a valley, not a peak"
# Failed to find line ArI at wl=5888.5841: "Tried to find peak at 924.728566252317 but it's in a valley, not a peak"
# Failed to find line ArI at wl=5912.0853: "Tried to find peak at 940.1696444223658 but it's in a valley, not a peak"
# Failed to find line ArI at wl=5928.813: "Guessed line's peak to base ratio is 1.070546397298652, which is less than 10"
# Failed to find line NeI at wl=5944.8342: "Guessed line's peak to base ratio is 4.193679312728832, which is less than 10"
# Failed to find line NeI at wl=5975.534: "Guessed line's peak to base ratio is 2.425275287822823, which is less than 10"
# Failed to find line ArI at wl=6043.2233: "Tried to find peak at 1026.2569880643707 but it's in a valley, not a peak"
# Failed to find line NeI at wl=6074.3377: "Guessed line's peak to base ratio is 4.083138420221488, which is less than 10"
# Failed to find line NeI at wl=6096.1631: "Guessed line's peak to base ratio is 4.062653889146546, which is less than 10"
# Failed to find line ArII at wl=6114.9234: "Guessed line's peak to base ratio is 0.939661194648886, which is less than 10"
# Failed to find line NeI at wl=6128.4499: "Tried to find peak at 1082.1392323100135 but it's in a valley, not a peak"
# Failed to find line NeI at wl=6143.0626: "Guessed line's peak to base ratio is 5.9041926786510395, which is less than 10"
# Failed to find line ArI at wl=6155.2385: "Guessed line's peak to base ratio is 0.9203552181135556, which is less than 10"
# Failed to find line NeI at wl=6163.5939: "Guessed line's peak to base ratio is 3.3516321264552897, which is less than 10"
# Failed to find line ArI at wl=6212.5031: "Tried to find peak at 1137.203156364829 but it's in a valley, not a peak"
# Failed to find line NeI at wl=6217.2812: "Guessed line's peak to base ratio is 5.062217554576377, which is less than 10"
# Failed to find line NeI at wl=6266.495: "Guessed line's peak to base ratio is 6.220329903771383, which is less than 10"
# Failed to find line ArI at wl=6296.8722: "Guessed line's peak to base ratio is 1.0279910803827164, which is less than 10"
# Failed to find line NeI at wl=6304.789: "Guessed line's peak to base ratio is 5.151796328548591, which is less than 10"
# Failed to find line NeI at wl=6334.4278: "Guessed line's peak to base ratio is 5.638381324451005, which is less than 10"
# Failed to find line NeI at wl=6382.9917: "Guessed line's peak to base ratio is 8.245414281466573, which is less than 10"
# Failed to find line NeI at wl=6402.246: "Guessed line's peak to base ratio is 6.881203774614326, which is less than 10"
# Failed to find line ArI at wl=6416.3071: "Guessed line's peak to base ratio is 1.0197508709822138, which is less than 10"
# Failed to find line KrI at wl=6456.291: "Guessed line's peak to base ratio is 0.8616851460556151, which is less than 10"
# Found line NeI at wl=6506.5281
# Clipped 0 lines
# Failed to find line NeI at wl=6532.8822: "Guessed line's peak to base ratio is 8.494500356142288, which is less than 10"
# Failed to find line NeI at wl=6598.9529: "Guessed line's peak to base ratio is 9.11967530053067, which is less than 10"
# Found line NeI at wl=6717.043
# Clipped 0 lines
# Failed to find line ArI at wl=6752.8335: "Guessed line's peak to base ratio is 1.845641317550602, which is less than 10"
# Failed to find line ArI at wl=6766.6117: "Tried to find peak at 1499.2488664773357 but it's in a valley, not a peak"
# Failed to find line ArI at wl=6871.2891: "Guessed line's peak to base ratio is 1.4250272267470916, which is less than 10"
# Found line NeI at wl=6929.4673
# Clipped 0 lines
# Failed to find line ArI at wl=6937.6642: "Guessed line's peak to base ratio is 1.0832220195070341, which is less than 10"
# Failed to find line ArI at wl=6965.4307: "Guessed line's peak to base ratio is 9.390947570520234, which is less than 10"
# Failed to find line NeI at wl=7024.0504: "Guessed line's peak to base ratio is 1.9623280066889242, which is less than 10"
# Found line NeI at wl=7032.4131
# Clipped 0 lines
# Failed to find line ArI at wl=7107.4778: "Guessed line's peak to base ratio is 1.213704874849918, which is less than 10"
# Failed to find line ArI at wl=7125.82: "Guessed line's peak to base ratio is 1.5184423969745522, which is less than 10"
# Failed to find line ArI at wl=7147.0416: "Guessed line's peak to base ratio is 5.64112705476983, which is less than 10"
# Failed to find line NeI at wl=7173.9381: "Guessed line's peak to base ratio is 5.7128864055846185, which is less than 10"
# Failed to find line ArI at wl=7206.9804: "Guessed line's peak to base ratio is 1.2169333577354096, which is less than 10"
# Found line NeI at wl=7245.1666
# Clipped 0 lines
# Failed to find line ArI at wl=7272.9359: "Guessed line's peak to base ratio is 7.605442276448056, which is less than 10"
# Found line HeI at wl=7281.349
# Clipped 0 lines
# Failed to find line ArI at wl=7353.293: "Guessed line's peak to base ratio is 1.440416352893276, which is less than 10"
# Failed to find line ArI at wl=7372.1184: "Guessed line's peak to base ratio is 1.886015039320914, which is less than 10"
# Found line ArI at wl=7383.9805
# Clipped 0 lines
# Failed to find line NeI at wl=7488.8712: "Guessed line's peak to base ratio is 2.4296461377363423, which is less than 10"
# Found line ArI at wl=7503.8691
# Clipped 0 lines
# Found line ArI at wl=7514.6518
# Clipped 0 lines
# Failed to find line NeI at wl=7535.7739: "Guessed line's peak to base ratio is 2.480156090889031, which is less than 10"
# Failed to find line NeI at wl=7544.0443: "Guessed line's peak to base ratio is 1.2925552080633658, which is less than 10"
# Failed to find line KrI at wl=7587.413: "Guessed line's peak to base ratio is 1.0819554378142586, which is less than 10"
# Failed to find line KrI at wl=7601.5443: "Guessed line's peak to base ratio is 1.0525916052067257, which is less than 10"
# Found line ArI at wl=7635.106
# Clipped 0 lines
# Failed to find line KrI at wl=7685.246: "Tried to find peak at 2095.7102377360125 but it's in a valley, not a peak"
# Failed to find line KrI at wl=7694.5393: "Guessed line's peak to base ratio is 0.9487211223641862, which is less than 10"
# Failed to find line KrI at wl=7854.8215: "Guessed line's peak to base ratio is 1.1041302787798228, which is less than 10"
# Failed to find line ArI at wl=7891.075: "Guessed line's peak to base ratio is 1.1153847553894787, which is less than 10"
# Failed to find line KrI at wl=7913.4242: "Tried to find peak at 2243.4658680624693 but it's in a valley, not a peak"
# Found line ArI at wl=7948.1764
# Clipped 0 lines
# Failed to find line ArI at wl=8006.1567: "Guessed line's peak to base ratio is 6.71869024521498, which is less than 10"
# Failed to find line ArI at wl=8014.7857: "Guessed line's peak to base ratio is 7.395561544387761, which is less than 10"
# Failed to find line KrI at wl=8059.5038: "Tried to find peak at 2338.0234170166977 but it's in a valley, not a peak"
# Found line ArI at wl=8103.6931
# Clipped 0 lines
# Found line ArI at wl=8115.311
# Clipped 0 lines
# Failed to find line KrI at wl=8190.0543: "Guessed line's peak to base ratio is 0.9423511275390428, which is less than 10"
# Found line ArI at wl=8264.5225
# Clipped 0 lines
# Failed to find line KrI at wl=8281.0495: "Guessed line's peak to base ratio is 0.9588258798377841, which is less than 10"
# Failed to find line NeI at wl=8377.6065: "Guessed line's peak to base ratio is 9.895947290981596, which is less than 10"
# Found line ArI at wl=8408.2096
# Clipped 0 lines
# Found line ArI at wl=8424.6475
# Clipped 0 lines
# Failed to find line NeI at wl=8495.3598: "Guessed line's peak to base ratio is 8.92091474828603, which is less than 10"
# Failed to find line KrI at wl=8508.87: "Tried to find peak at 2628.6775759657976 but it's in a valley, not a peak"
# Found line ArI at wl=8521.4422
# Clipped 1 lines
# Failed to find line NeI at wl=8591.2583: "Guessed line's peak to base ratio is 3.615757154559494, which is less than 10"
# Failed to find line ArI at wl=8605.7762: "Guessed line's peak to base ratio is 1.3807936826784366, which is less than 10"
# Failed to find line ArI at wl=8620.4602: "Tried to find peak at 2700.84947608174 but it's in a valley, not a peak"
# Failed to find line NeI at wl=8634.647: "Guessed line's peak to base ratio is 6.430550335639731, which is less than 10"
# Failed to find line NeI at wl=8654.3831: "Guessed line's peak to base ratio is 8.10538215570277, which is less than 10"
# Found line ArI at wl=8667.9442
# Clipped 0 lines
# Failed to find line KrI at wl=8776.749: "Guessed line's peak to base ratio is 4.154437801272761, which is less than 10"
# Failed to find line ArI at wl=8799.0875: "Tried to find peak at 2816.2553704932457 but it's in a valley, not a peak"
# Failed to find line NeI at wl=8919.5007: "Guessed line's peak to base ratio is 1.6069724562890257, which is less than 10"
# Failed to find line KrI at wl=8928.692: "Guessed line's peak to base ratio is 1.0081543445395724, which is less than 10"
# Found line ArI at wl=9122.9674
# Clipped 0 lines
# Failed to find line ArI at wl=9194.6385: "Guessed line's peak to base ratio is 2.5057118712383306, which is less than 10"
# Found line ArI at wl=9224.4992
# Clipped 0 lines
# Failed to find line ArI at wl=9291.5313: "Guessed line's peak to base ratio is 1.9448428494292078, which is less than 10"
# Found line ArI at wl=9354.2198
# Clipped 0 lines
# Found line ArI at wl=9657.7863
# Clipped 0 lines
# Failed to find line KrI at wl=9751.759: "Tried to find peak at 3431.605302467357 but it's in a valley, not a peak"
# Found line ArI at wl=9784.5028
# Clipped 0 lines
# Failed to find line KrI at wl=9856.24: "Guessed line's peak to base ratio is 1.2394118570057227, which is less than 10"
# Failed to find line ArI at wl=10052.1: "Guessed line's peak to base ratio is 2.2067321788873073, which is less than 10"
# Failed to find line ArI at wl=10254.04: "Tried to find peak at 3756.6131594605026 but it's in a valley, not a peak"
# Failed to find line ArI at wl=10309.15: "Tried to find peak at 3792.2888776923355 but it's in a valley, not a peak"
# Failed to find line ArI at wl=10332.76: "Guessed line's peak to base ratio is 1.3964917963367078, which is less than 10"
# Failed to find line KrI at wl=10360.37: "Guessed line's peak to base ratio is 1.1285644235117729, which is less than 10"
# Failed to find line ArI at wl=10470.054: "Guessed line's peak to base ratio is 3.639147823147427, which is less than 10"
# Failed to find line ArI at wl=10506.47: "Guessed line's peak to base ratio is 1.0564504452904233, which is less than 10"
# Failed to find line ArI at wl=10529.32: "Guessed line's peak to base ratio is 1.0443696141352439, which is less than 10"
# Failed to find line KrI at wl=10593.01: "Guessed line's peak to base ratio is 1.355645191809174, which is less than 10"
# Failed to find line ArI at wl=10673.55: "Tried to find peak at 4028.375971278321 but it's in a valley, not a peak"
# Failed to find line ArI at wl=10681.78: "Guessed line's peak to base ratio is 1.1544361944808443, which is less than 10"
# Failed to find line ArI at wl=10712.77: "Guessed line's peak to base ratio is 1.3120492198298404, which is less than 10"
# Failed to find line ArI at wl=10733.87: "Guessed line's peak to base ratio is 1.2040888967546597, which is less than 10"
# Failed to find line ArI at wl=10759.13: "Tried to find peak at 4083.8758315667355 but it's in a valley, not a peak"
# Failed to find line ArI at wl=10773.35: "Tried to find peak at 4093.099922989602 but it's in a valley, not a peak"
# Failed to find line NeI at wl=10798.12: "Tried to find peak at 4109.1690337553855 but it's in a valley, not a peak"
# Failed to find line HeI at wl=10830.337: "requested peak location is not in the spectrum"
# Failed to find line NeI at wl=10844.54: "requested peak location is not in the spectrum"
# Failed to find line ArI at wl=10880.96: "requested peak location is not in the spectrum"
# Failed to find line ArI at wl=10950.74: "requested peak location is not in the spectrum"
# Failed to find line ArI at wl=11078.87: "requested peak location is not in the spectrum"
# Failed to find line ArI at wl=11106.44: "requested peak location is not in the spectrum"

# %%
#creating a ds _ part one

#plotting arc lamp pixel data and atlas wl data to match lines in next cell
specset_blue = pipeline.dispersion(all_side_files_blue, atlasfiles_blue, arcfiles_blue10, linelist_blue,flatid)
# Out:
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:88: UserWarning: ROISEC is not one of the values this pipeline assumes.It may not work right where specific values are used (e.g., creating master flats
#   warn("ROISEC is not one of the values this pipeline assumes."
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:256: RuntimeWarning: invalid value encountered in sqrt
#   unc = (result/self.header['GAIN'] + self.unc[tsl]**2)**0.5
# used atlas plot limits for Blue side

# %%
#creating a ds _ part two

#use above plots to enter guesses of matching lines
pipeline.guess_plot(1135,4609,specset_blue) #(arc-PIX-guess,atlas-WL-from-linelist)

#collect guesses here ~5 seems good
pixel_guesses = [1956,1827,993,1029,528]#badvals 1135
atlas_lines = [3719.9346, 3859.9114, 4764.8646, 4726.8683, 5269.5366] #badvals 4609.5673
guesses = list(zip(pixel_guesses, atlas_lines)) #must be tuples

# %%
#creating a ds _ part three

ds_blue = pipeline.goodness_of_matches(arcfiles_blue10, guesses, all_side_files_blue, atlasfiles_blue, linelist_blue, flatid);
#this is the final blue side ds
# Out:
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:88: UserWarning: ROISEC is not one of the values this pipeline assumes.It may not work right where specific values are used (e.g., creating master flats
#   warn("ROISEC is not one of the values this pipeline assumes."
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:256: RuntimeWarning: invalid value encountered in sqrt
#   unc = (result/self.header['GAIN'] + self.unc[tsl]**2)**0.5
# chose ds for blueside
# chose guesses for blueside
# Failed to find line FeI at wl=3020.6391: "Guessed line's peak to base ratio is 0.9283220677308877, which is less than 5"
# Failed to find line FeI at wl=3024.0325: "Guessed line's peak to base ratio is 1.1792408779758057, which is less than 5"
# Failed to find line FeI at wl=3037.3887: "Guessed line's peak to base ratio is 2.3370690055694463, which is less than 5"
# Failed to find line FeI at wl=3047.6043: "Guessed line's peak to base ratio is 2.7543769339564936, which is less than 5"
# Failed to find line FeI at wl=3057.4456: "Guessed line's peak to base ratio is 2.0635750414101492, which is less than 5"
# Failed to find line FeI at wl=3059.0856: "Guessed line's peak to base ratio is 2.0635750414101492, which is less than 5"
# Failed to find line FeI at wl=3225.785: "Guessed line's peak to base ratio is 0.9566180332361156, which is less than 5"
# Failed to find line ArII at wl=3243.6887: "Guessed line's peak to base ratio is 1.1629140069854265, which is less than 5"
# Failed to find line ArII at wl=3350.9243: "Tried to find peak at 2300.929687592912 but it's in a valley, not a peak"
# Failed to find line ArII at wl=3376.4359: "Guessed line's peak to base ratio is 1.590657915037926, which is less than 5"
# Failed to find line ArII at wl=3388.5309: "Guessed line's peak to base ratio is 1.4386244456025037, which is less than 5"
# Failed to find line FeI at wl=3399.3335: "Guessed line's peak to base ratio is 0.9086455164156074, which is less than 5"
# Failed to find line FeI at wl=3404.3535: "Guessed line's peak to base ratio is 1.9640659779936187, which is less than 5"
# Failed to find line FeI at wl=3407.4585: "Tried to find peak at 2248.159228857257 but it's in a valley, not a peak"
# Failed to find line FeI at wl=3413.1312: "Guessed line's peak to base ratio is 1.1437433882660175, which is less than 5"
# Failed to find line FeI at wl=3427.1192: "Guessed line's peak to base ratio is 2.3963836626703476, which is less than 5"
# Failed to find line FeI at wl=3443.8762: "Tried to find peak at 2214.2044983685055 but it's in a valley, not a peak"
# Failed to find line FeI at wl=3465.8603: "Guessed line's peak to base ratio is 4.577960167608304, which is less than 5"
# Found line FeI at wl=3475.45
# Clipped 0 lines
# Found line FeI at wl=3476.7016
# Clipped 0 lines
# Failed to find line ArII at wl=3480.5055: "Tried to find peak at 2182.6224485947673 but it's in a valley, not a peak"
# Found line FeI at wl=3490.5737
# Clipped 0 lines
# Failed to find line ArII at wl=3509.7785: "Guessed line's peak to base ratio is 1.6856941852927385, which is less than 5"
# Failed to find line ArII at wl=3519.9936: "Guessed line's peak to base ratio is 1.5136685168252841, which is less than 5"
# Failed to find line ArII at wl=3535.3196: "Guessed line's peak to base ratio is 1.4310609985404488, which is less than 5"
# Failed to find line FeI at wl=3541.0832: "Guessed line's peak to base ratio is 0.7988491128097529, which is less than 5"
# Failed to find line ArII at wl=3548.5144: "Guessed line's peak to base ratio is 1.015052451617759, which is less than 5"
# Failed to find line ArII at wl=3559.5081: "Guessed line's peak to base ratio is 2.0190679529437854, which is less than 5"
# Failed to find line ArII at wl=3561.0304: "Guessed line's peak to base ratio is 2.0190679529437854, which is less than 5"
# Failed to find line FeI at wl=3565.3786: "Guessed line's peak to base ratio is 1.2035032556621175, which is less than 5"
# Failed to find line ArII at wl=3576.6156: "Guessed line's peak to base ratio is 0.4784080236429403, which is less than 5"
# Failed to find line FeI at wl=3581.1925: "Guessed line's peak to base ratio is 4.122706406796571, which is less than 5"
# Failed to find line ArII at wl=3588.4407: "Guessed line's peak to base ratio is 1.2897476120287523, which is less than 5"
# Failed to find line FeI at wl=3608.8587: "Guessed line's peak to base ratio is 2.7016222243669037, which is less than 5"
# Found line FeI at wl=3618.7676
# Clipped 0 lines
# Found line FeI at wl=3631.4629
# Clipped 0 lines
# Failed to find line FeI at wl=3647.8424: "Guessed line's peak to base ratio is 4.5142716376852015, which is less than 5"
# Failed to find line FeI at wl=3679.9132: "Guessed line's peak to base ratio is 2.791383367369975, which is less than 5"
# Failed to find line FeI at wl=3687.4564: "Guessed line's peak to base ratio is 1.7854215045311577, which is less than 5"
# Failed to find line FeI at wl=3705.5657: "Guessed line's peak to base ratio is 4.167326781832841, which is less than 5"
# Failed to find line FeI at wl=3709.2459: "Guessed line's peak to base ratio is 4.167326781832841, which is less than 5"
# Found line ArII at wl=3718.2065
# Clipped 0 lines
# Found line FeI at wl=3719.9346
# Clipped 0 lines
# Found line FeI at wl=3722.5625
# Clipped 0 lines
# Failed to find line FeI at wl=3727.6187: "Guessed line's peak to base ratio is 0.9772190625006457, which is less than 5"
# Failed to find line ArII at wl=3729.3087: "Guessed line's peak to base ratio is 0.9772190625006457, which is less than 5"
# Failed to find line FeI at wl=3733.3169: "Tried to find peak at 1946.069940943625 but it's in a valley, not a peak"
# Failed to find line FeI at wl=3734.8636: "Guessed line's peak to base ratio is 2.8702711815193527, which is less than 5"
# Failed to find line FeI at wl=3737.1313: "Guessed line's peak to base ratio is 2.8702711815193527, which is less than 5"
# Failed to find line FeI at wl=3745.5608: "Guessed line's peak to base ratio is 1.6479918351451692, which is less than 5"
# Failed to find line FeI at wl=3748.2617: "Guessed line's peak to base ratio is 1.5593677757112911, which is less than 5"
# Failed to find line FeI at wl=3749.4847: "Guessed line's peak to base ratio is 1.5593677757112911, which is less than 5"
# Failed to find line FeI at wl=3758.2324: "Guessed line's peak to base ratio is 3.0755748525534727, which is less than 5"
# Failed to find line FeI at wl=3763.7885: "Guessed line's peak to base ratio is 2.528877106229556, which is less than 5"
# Failed to find line FeI at wl=3767.1914: "Guessed line's peak to base ratio is 2.528877106229556, which is less than 5"
# Failed to find line FeI at wl=3812.9641: "Tried to find peak at 1872.0765744155049 but it's in a valley, not a peak"
# Failed to find line FeI at wl=3815.8397: "Guessed line's peak to base ratio is 1.6451445559867595, which is less than 5"
# Failed to find line FeI at wl=3820.4251: "Guessed line's peak to base ratio is 1.7993384051678745, which is less than 5"
# Failed to find line FeI at wl=3824.4436: "Guessed line's peak to base ratio is 2.2767539625344067, which is less than 5"
# Failed to find line FeI at wl=3825.8805: "Guessed line's peak to base ratio is 2.2767539625344067, which is less than 5"
# Failed to find line FeI at wl=3827.8226: "Guessed line's peak to base ratio is 2.2767539625344067, which is less than 5"
# Failed to find line FeI at wl=3834.2222: "Guessed line's peak to base ratio is 2.7207207196589054, which is less than 5"
# Failed to find line FeI at wl=3856.3717: "Guessed line's peak to base ratio is 0.9498318367977457, which is less than 5"
# Failed to find line FeI at wl=3859.9114: "Guessed line's peak to base ratio is 2.817153428742088, which is less than 5"
# Failed to find line ArII at wl=3868.5284: "Guessed line's peak to base ratio is 1.1791901621879677, which is less than 5"
# Failed to find line FeI at wl=3878.573: "Guessed line's peak to base ratio is 4.7519220587043876, which is less than 5"
# Found line FeI at wl=3886.282
# Clipped 0 lines
# Failed to find line FeI at wl=3895.6558: "Guessed line's peak to base ratio is 1.5155387226706913, which is less than 5"
# Failed to find line FeI at wl=3899.7073: "Guessed line's peak to base ratio is 1.6149320031693075, which is less than 5"
# Failed to find line FeI at wl=3902.9452: "Guessed line's peak to base ratio is 0.9459705132170418, which is less than 5"
# Failed to find line FeI at wl=3906.4794: "Guessed line's peak to base ratio is 0.9920830228510543, which is less than 5"
# Failed to find line FeI at wl=3920.2577: "Tried to find peak at 1772.378119840967 but it's in a valley, not a peak"
# Failed to find line FeI at wl=3922.9115: "Guessed line's peak to base ratio is 1.6376475276072637, which is less than 5"
# Failed to find line ArII at wl=3925.7188: "Guessed line's peak to base ratio is 3.072747951199724, which is less than 5"
# Failed to find line FeI at wl=3930.2962: "Guessed line's peak to base ratio is 3.072747951199724, which is less than 5"
# Failed to find line ArII at wl=3946.0971: "Guessed line's peak to base ratio is 2.5420641132221093, which is less than 5"
# Failed to find line ArI at wl=3948.9789: "Guessed line's peak to base ratio is 2.5420641132221093, which is less than 5"
# Failed to find line FeI at wl=3969.257: "Guessed line's peak to base ratio is 3.3346191357957298, which is less than 5"
# Failed to find line ArII at wl=3979.3559: "Guessed line's peak to base ratio is 1.6056819693013338, which is less than 5"
# Failed to find line ArII at wl=3994.7918: "Guessed line's peak to base ratio is 2.5565893203742114, which is less than 5"
# Failed to find line FeI at wl=4005.2414: "Guessed line's peak to base ratio is 2.594592775772687, which is less than 5"
# Found line ArII at wl=4033.8093
# Clipped 0 lines
# Failed to find line ArII at wl=4042.8937: "Tried to find peak at 1659.1828727561137 but it's in a valley, not a peak"
# Found line ArI at wl=4044.4179
# Clipped 0 lines
# Found line FeI at wl=4045.813
# Clipped 0 lines
# Failed to find line ArII at wl=4052.9208: "Guessed line's peak to base ratio is 2.1286846002939197, which is less than 5"
# Found line FeI at wl=4063.5939
# Clipped 0 lines
# Failed to find line ArII at wl=4103.9121: "Guessed line's peak to base ratio is 3.4445683200803465, which is less than 5"
# Failed to find line FeI at wl=4118.5442: "Guessed line's peak to base ratio is 1.6978293675061544, which is less than 5"
# Found line ArII at wl=4131.7235
# Clipped 0 lines
# Failed to find line FeI at wl=4143.8688: "Guessed line's peak to base ratio is 4.470555295410519, which is less than 5"
# Found line ArI at wl=4158.5905
# Clipped 0 lines
# Failed to find line ArI at wl=4164.1795: "Guessed line's peak to base ratio is 1.2374832679638155, which is less than 5"
# Failed to find line FeI at wl=4198.3036: "Guessed line's peak to base ratio is 4.631024767429882, which is less than 5"
# Failed to find line ArI at wl=4200.6745: "Guessed line's peak to base ratio is 4.631024767429882, which is less than 5"
# Failed to find line FeI at wl=4216.1828: "Guessed line's peak to base ratio is 3.3755504554241744, which is less than 5"
# Failed to find line FeI at wl=4222.6373: "Guessed line's peak to base ratio is 0.9798593817887403, which is less than 5"
# Failed to find line ArII at wl=4237.2198: "Guessed line's peak to base ratio is 2.895368298234601, which is less than 5"
# Found line ArI at wl=4259.3619
# Clipped 0 lines
# Failed to find line FeI at wl=4271.7593: "Guessed line's peak to base ratio is 3.4657878954292864, which is less than 5"
# Failed to find line ArII at wl=4277.5282: "Guessed line's peak to base ratio is 3.239882304027881, which is less than 5"
# Failed to find line FeI at wl=4294.1243: "Guessed line's peak to base ratio is 1.2846367920484472, which is less than 5"
# Found line ArI at wl=4300.1008
# Clipped 0 lines
# Failed to find line FeI at wl=4307.9015: "Guessed line's peak to base ratio is 3.9762731727458074, which is less than 5"
# Failed to find line FeI at wl=4315.0837: "Guessed line's peak to base ratio is 1.4161249109013343, which is less than 5"
# Found line FeI at wl=4325.7615
# Clipped 1 lines
# Failed to find line ArII at wl=4331.1995: "Guessed line's peak to base ratio is 2.5614697008041514, which is less than 5"
# Failed to find line ArI at wl=4333.5612: "Guessed line's peak to base ratio is 2.5614697008041514, which is less than 5"
# Failed to find line ArI at wl=4335.3379: "Guessed line's peak to base ratio is 2.5614697008041514, which is less than 5"
# Failed to find line ArII at wl=4337.0708: "Tried to find peak at 1387.615037440911 but it's in a valley, not a peak"
# Failed to find line ArII at wl=4345.168: "Guessed line's peak to base ratio is 4.164036459520244, which is less than 5"
# Failed to find line ArII at wl=4348.064: "Guessed line's peak to base ratio is 4.164036459520244, which is less than 5"
# Failed to find line ArII at wl=4352.2049: "Guessed line's peak to base ratio is 0.8878317281248049, which is less than 5"
# Failed to find line ArII at wl=4362.0662: "Guessed line's peak to base ratio is 1.7280756597371623, which is less than 5"
# Failed to find line ArII at wl=4367.8316: "Guessed line's peak to base ratio is 2.401212828700867, which is less than 5"
# Failed to find line FeI at wl=4375.9294: "Guessed line's peak to base ratio is 1.9270841509163537, which is less than 5"
# Failed to find line ArII at wl=4379.6668: "Guessed line's peak to base ratio is 0.7007275614268147, which is less than 5"
# Found line FeI at wl=4383.5445
# Clipped 0 lines
# Found line ArII at wl=4385.0566
# Clipped 0 lines
# Failed to find line ArII at wl=4400.9863: "Guessed line's peak to base ratio is 1.3889079063371053, which is less than 5"
# Failed to find line FeI at wl=4404.7499: "Guessed line's peak to base ratio is 2.8204945130694994, which is less than 5"
# Found line FeI at wl=4415.1222
# Clipped 0 lines
# Failed to find line ArII at wl=4426.0011: "Guessed line's peak to base ratio is 2.9428349329845247, which is less than 5"
# Failed to find line FeI at wl=4427.3039: "Guessed line's peak to base ratio is 2.9428349329845247, which is less than 5"
# Failed to find line ArII at wl=4430.189: "Guessed line's peak to base ratio is 1.0812613136079958, which is less than 5"
# Failed to find line ArII at wl=4433.838: "Guessed line's peak to base ratio is 0.9577671122405731, which is less than 5"
# Failed to find line ArII at wl=4439.4614: "Guessed line's peak to base ratio is 1.7236504675250564, which is less than 5"
# Failed to find line ArII at wl=4448.8792: "Guessed line's peak to base ratio is 3.1925036995522884, which is less than 5"
# Failed to find line FeI at wl=4461.6521: "Guessed line's peak to base ratio is 3.0655171879936973, which is less than 5"
# Failed to find line FeI at wl=4466.5508: "Guessed line's peak to base ratio is 1.194084745605347, which is less than 5"
# Found line ArII at wl=4474.7594
# Clipped 0 lines
# Found line ArII at wl=4481.8107
# Clipped 0 lines
# Failed to find line FeI at wl=4489.7389: "Guessed line's peak to base ratio is 1.8923940696272479, which is less than 5"
# Failed to find line ArII at wl=4490.9816: "Guessed line's peak to base ratio is 1.8923940696272479, which is less than 5"
# Failed to find line ArII at wl=4498.5384: "Guessed line's peak to base ratio is 1.2033888538207085, which is less than 5"
# Failed to find line ArII at wl=4502.9268: "Guessed line's peak to base ratio is 1.5948884411693691, which is less than 5"
# Found line ArI at wl=4510.7332
# Clipped 0 lines
# Failed to find line ArI at wl=4522.323: "Guessed line's peak to base ratio is 2.2242960403333494, which is less than 5"
# Failed to find line FeI at wl=4528.6133: "Guessed line's peak to base ratio is 2.4184457436969895, which is less than 5"
# Failed to find line FeI at wl=4530.5523: "Guessed line's peak to base ratio is 2.4184457436969895, which is less than 5"
# Found line ArII at wl=4545.0519
# Clipped 0 lines
# Found line ArII at wl=4579.3495
# Clipped 2 lines
# Found line ArII at wl=4589.8978
# Clipped 0 lines
# Failed to find line ArI at wl=4596.0967: "Tried to find peak at 1149.5961949848208 but it's in a valley, not a peak"
# Failed to find line ArII at wl=4598.7627: "Guessed line's peak to base ratio is 2.00979720598221, which is less than 5"
# Found line ArII at wl=4609.5673
# Clipped 1 lines
# Failed to find line ArI at wl=4628.4409: "Guessed line's peak to base ratio is 2.8318315622477064, which is less than 5"
# Failed to find line ArII at wl=4637.2328: "Guessed line's peak to base ratio is 4.671345638714823, which is less than 5"
# Failed to find line FeI at wl=4647.4329: "Guessed line's peak to base ratio is 1.3718893865164903, which is less than 5"
# Found line ArII at wl=4657.9012
# Clipped 0 lines
# Failed to find line ArI at wl=4702.3161: "Guessed line's peak to base ratio is 4.152921139472269, which is less than 5"
# Found line ArII at wl=4726.8683
# Clipped 0 lines
# Failed to find line ArII at wl=4732.0532: "Guessed line's peak to base ratio is 0.9627534925066609, which is less than 5"
# Failed to find line ArII at wl=4735.9058: "Guessed line's peak to base ratio is 3.0150846286729935, which is less than 5"
# Found line ArII at wl=4764.8646
# Clipped 0 lines
# Found line ArII at wl=4806.0205
# Clipped 0 lines
# Found line ArII at wl=4847.8095
# Clipped 0 lines
# Failed to find line FeI at wl=4859.7406: "Guessed line's peak to base ratio is 1.88771949493343, which is less than 5"
# Found line ArII at wl=4879.8635
# Clipped 0 lines
# Failed to find line ArII at wl=4889.0422: "Guessed line's peak to base ratio is 4.047182207156573, which is less than 5"
# Failed to find line FeI at wl=4891.4919: "Guessed line's peak to base ratio is 4.047182207156573, which is less than 5"
# Found line FeI at wl=4920.5018
# Clipped 0 lines
# Found line ArII at wl=4933.2091
# Clipped 0 lines
# Found line FeI at wl=4957.5966
# Clipped 0 lines
# Found line ArII at wl=4965.0795
# Clipped 0 lines
# Failed to find line ArII at wl=4972.1597: "Guessed line's peak to base ratio is 1.5007034717291987, which is less than 5"
# Failed to find line FeI at wl=5006.1175: "Guessed line's peak to base ratio is 1.2069239970052268, which is less than 5"
# Failed to find line ArII at wl=5009.3344: "Guessed line's peak to base ratio is 1.759435053929961, which is less than 5"
# Failed to find line FeI at wl=5012.0674: "Tried to find peak at 767.2871373028237 but it's in a valley, not a peak"
# Failed to find line ArII at wl=5017.1628: "Guessed line's peak to base ratio is 4.96083172056895, which is less than 5"
# Failed to find line FeI at wl=5051.6336: "Guessed line's peak to base ratio is 2.2826827399231133, which is less than 5"
# Failed to find line ArII at wl=5062.0371: "Guessed line's peak to base ratio is 3.437488180686779, which is less than 5"
# Failed to find line FeI at wl=5083.3377: "Guessed line's peak to base ratio is 1.313258333403959, which is less than 5"
# Failed to find line ArII at wl=5090.4951: "Guessed line's peak to base ratio is 4.296154539639907, which is less than 5"
# Failed to find line FeI at wl=5110.3849: "Guessed line's peak to base ratio is 4.206171789594706, which is less than 5"
# Failed to find line ArII at wl=5125.7654: "Guessed line's peak to base ratio is 2.475589127888431, which is less than 5"
# Failed to find line ArII at wl=5141.7827: "Guessed line's peak to base ratio is 1.7763352648239863, which is less than 5"
# Failed to find line ArII at wl=5145.3083: "Guessed line's peak to base ratio is 1.265347553365675, which is less than 5"
# Failed to find line ArI at wl=5162.2846: "Guessed line's peak to base ratio is 1.7764738451527826, which is less than 5"
# Failed to find line FeI at wl=5167.4873: "Guessed line's peak to base ratio is 2.917504833639577, which is less than 5"
# Failed to find line FeI at wl=5171.5953: "Guessed line's peak to base ratio is 0.972546810961498, which is less than 5"
# Failed to find line ArI at wl=5187.7462: "Guessed line's peak to base ratio is 2.1388934531240684, which is less than 5"
# Failed to find line FeI at wl=5194.9412: "Guessed line's peak to base ratio is 1.9735988334973387, which is less than 5"
# Failed to find line ArI at wl=5221.271: "Guessed line's peak to base ratio is 1.2817531323730822, which is less than 5"
# Found line FeI at wl=5227.1697
# Clipped 0 lines
# Failed to find line FeI at wl=5232.9394: "Guessed line's peak to base ratio is 2.3874502973414766, which is less than 5"
# Found line FeI at wl=5266.5546
# Clipped 1 lines
# Found line FeI at wl=5269.5366
# Clipped 0 lines
# Failed to find line FeI at wl=5283.6206: "Guessed line's peak to base ratio is 2.2296385331690685, which is less than 5"
# Failed to find line FeI at wl=5302.2989: "Guessed line's peak to base ratio is 1.5296236165261903, which is less than 5"
# Failed to find line FeI at wl=5324.1782: "Guessed line's peak to base ratio is 1.343267265793878, which is less than 5"
# Failed to find line FeI at wl=5328.0376: "Guessed line's peak to base ratio is 4.764900788090817, which is less than 5"
# Found line FeI at wl=5341.0233
# Clipped 0 lines
# Failed to find line FeI at wl=5371.4892: "Guessed line's peak to base ratio is 4.000649674573141, which is less than 5"
# Failed to find line FeI at wl=5397.1269: "Guessed line's peak to base ratio is 3.883621606407187, which is less than 5"
# Skipping line FeI at wl=5405.7741 - out of wl min/max
# Skipping line FeI at wl=5415.1997 - out of wl min/max
# Skipping line ArI at wl=5421.3517 - out of wl min/max
# Skipping line FeI at wl=5424.0686 - out of wl min/max
# Skipping line FeI at wl=5429.6955 - out of wl min/max
# Skipping line FeI at wl=5434.5228 - out of wl min/max
# Skipping line ArI at wl=5439.9891 - out of wl min/max
# Skipping line FeI at wl=5446.8937 - out of wl min/max
# Skipping line ArI at wl=5451.652 - out of wl min/max
# Skipping line FeI at wl=5455.609 - out of wl min/max
# Skipping line ArI at wl=5495.8738 - out of wl min/max
# Skipping line ArI at wl=5514.376 - out of wl min/max
# Skipping line ArI at wl=5524.957 - out of wl min/max
# Skipping line ArI at wl=5558.702 - out of wl min/max
# Skipping line FeI at wl=5569.6177 - out of wl min/max
# Skipping line ArII at wl=5577.6845 - out of wl min/max
# Skipping line FeI at wl=5586.7553 - out of wl min/max
# Skipping line ArI at wl=5606.733 - out of wl min/max
# Skipping line FeI at wl=5615.6436 - out of wl min/max
# Skipping line ArI at wl=5648.6863 - out of wl min/max
# Skipping line ArI at wl=5650.7043 - out of wl min/max
# Skipping line ArI at wl=5681.9001 - out of wl min/max
# Skipping line ArII at wl=5691.6612 - out of wl min/max
# Skipping line ArI at wl=5739.5196 - out of wl min/max
# Skipping line ArI at wl=5783.536 - out of wl min/max
# Skipping line ArII at wl=5786.5553 - out of wl min/max
# Skipping line ArI at wl=5802.0798 - out of wl min/max
# Skipping line ArII at wl=5812.7592 - out of wl min/max
# Skipping line ArI at wl=5834.2633 - out of wl min/max
# Skipping line ArI at wl=5860.3103 - out of wl min/max
# Skipping line ArI at wl=5882.6242 - out of wl min/max
# Skipping line ArI at wl=5888.5841 - out of wl min/max
# Skipping line ArI at wl=5912.0853 - out of wl min/max
# Skipping line ArI at wl=5916.5992 - out of wl min/max
# Skipping line ArI at wl=5927.1258 - out of wl min/max
# Skipping line ArI at wl=5928.813 - out of wl min/max
# Skipping line ArI at wl=5942.6686 - out of wl min/max
# Skipping line ArI at wl=5949.2583 - out of wl min/max
# Skipping line ArI at wl=5964.4723 - out of wl min/max
# Skipping line ArI at wl=5968.3199 - out of wl min/max
# Skipping line ArI at wl=5971.6008 - out of wl min/max
# Skipping line ArI at wl=5987.3016 - out of wl min/max
# Skipping line ArI at wl=5998.9987 - out of wl min/max
# Skipping line ArI at wl=6005.7242 - out of wl min/max
# Skipping line ArI at wl=6013.6777 - out of wl min/max
# Skipping line ArI at wl=6025.15 - out of wl min/max
# Skipping line ArI at wl=6032.1274 - out of wl min/max
# Skipping line ArI at wl=6043.2233 - out of wl min/max
# Skipping line ArI at wl=6046.8977 - out of wl min/max
# Skipping line ArI at wl=6052.7229 - out of wl min/max
# Skipping line ArI at wl=6059.3725 - out of wl min/max
# Skipping line ArI at wl=6081.2433 - out of wl min/max
# Skipping line ArI at wl=6085.8797 - out of wl min/max
# Skipping line ArI at wl=6090.7848 - out of wl min/max
# Skipping line ArI at wl=6098.8031 - out of wl min/max
# Skipping line ArI at wl=6105.6351 - out of wl min/max
# Skipping line ArII at wl=6114.9234 - out of wl min/max
# Skipping line ArII at wl=6123.3619 - out of wl min/max
# Skipping line ArI at wl=6127.416 - out of wl min/max
# Skipping line ArI at wl=6145.4411 - out of wl min/max
# Skipping line ArI at wl=6155.2385 - out of wl min/max
# Skipping line ArI at wl=6165.1232 - out of wl min/max
# Skipping line ArII at wl=6170.174 - out of wl min/max
# Skipping line FeI at wl=6172.2778 - out of wl min/max
# Skipping line ArII at wl=6191.5583 - out of wl min/max
# Skipping line ArI at wl=6201.1002 - out of wl min/max
# Skipping line ArI at wl=6212.5031 - out of wl min/max
# Skipping line FeI at wl=6215.9383 - out of wl min/max
# Skipping line ArII at wl=6230.726 - out of wl min/max
# Skipping line FeI at wl=6243.1201 - out of wl min/max
# Skipping line ArI at wl=6246.3172 - out of wl min/max
# Skipping line FeI at wl=6248.4055 - out of wl min/max
# Skipping line FeI at wl=6252.5537 - out of wl min/max
# Skipping line ArI at wl=6296.8722 - out of wl min/max
# Skipping line ArII at wl=6307.657 - out of wl min/max
# Skipping line ArI at wl=6324.4163 - out of wl min/max
# Skipping line ArI at wl=6364.8937 - out of wl min/max
# Skipping line ArI at wl=6369.5748 - out of wl min/max
# Skipping line FeI at wl=6384.7169 - out of wl min/max
# Skipping line ArII at wl=6399.9995 - out of wl min/max
# Skipping line FeI at wl=6403.0128 - out of wl min/max
# Skipping line ArI at wl=6411.6468 - out of wl min/max
# Skipping line ArII at wl=6416.3071 - out of wl min/max
# Skipping line ArI at wl=6437.6003 - out of wl min/max
# Skipping line ArII at wl=6466.5526 - out of wl min/max
# Skipping line ArII at wl=6483.0825 - out of wl min/max
# Skipping line ArI at wl=6538.112 - out of wl min/max
# Skipping line ArI at wl=6604.8534 - out of wl min/max
# Skipping line ArII at wl=6614.3475 - out of wl min/max
# Skipping line ArII at wl=6620.9665 - out of wl min/max
# Skipping line ArI at wl=6632.0837 - out of wl min/max
# Skipping line ArII at wl=6638.2207 - out of wl min/max
# Skipping line ArII at wl=6639.7403 - out of wl min/max
# Skipping line ArII at wl=6643.6976 - out of wl min/max
# Skipping line ArI at wl=6656.9386 - out of wl min/max
# Skipping line ArI at wl=6660.6761 - out of wl min/max
# Skipping line ArI at wl=6664.051 - out of wl min/max
# Skipping line ArII at wl=6666.3588 - out of wl min/max
# Skipping line ArI at wl=6677.2817 - out of wl min/max
# Skipping line ArII at wl=6684.2929 - out of wl min/max
# Skipping line ArI at wl=6719.2184 - out of wl min/max
# Skipping line ArI at wl=6752.8335 - out of wl min/max
# Skipping line ArI at wl=6766.6117 - out of wl min/max
# Skipping line ArII at wl=6861.2688 - out of wl min/max
# Skipping line ArI at wl=6871.2891 - out of wl min/max
# Skipping line ArI at wl=6879.5824 - out of wl min/max
# Skipping line ArI at wl=6888.1742 - out of wl min/max
# Skipping line ArI at wl=6937.6642 - out of wl min/max
# Skipping line ArI at wl=6951.4776 - out of wl min/max
# Skipping line ArI at wl=6965.4307 - out of wl min/max
# Skipping line ArI at wl=7030.2514 - out of wl min/max
# Skipping line ArI at wl=7067.2181 - out of wl min/max
# Skipping line ArI at wl=7107.4778 - out of wl min/max
# Skipping line ArI at wl=7125.82 - out of wl min/max
# Skipping line ArI at wl=7147.0416 - out of wl min/max
# Skipping line ArI at wl=7158.8387 - out of wl min/max
# Skipping line ArI at wl=7206.9804 - out of wl min/max
# Skipping line ArI at wl=7265.1724 - out of wl min/max
# Skipping line ArI at wl=7272.9359 - out of wl min/max
# Skipping line ArI at wl=7311.7159 - out of wl min/max
# Skipping line ArI at wl=7316.005 - out of wl min/max
# Skipping line ArI at wl=7353.293 - out of wl min/max
# Skipping line ArI at wl=7372.1184 - out of wl min/max
# Skipping line ArI at wl=7383.9805 - out of wl min/max
# Skipping line ArI at wl=7392.9801 - out of wl min/max
# Skipping line ArI at wl=7412.3368 - out of wl min/max
# Skipping line ArI at wl=7425.2942 - out of wl min/max
# Skipping line ArI at wl=7435.3683 - out of wl min/max
# Skipping line ArI at wl=7471.1641 - out of wl min/max
# Skipping line ArI at wl=7484.3267 - out of wl min/max
# Skipping line ArI at wl=7503.8691 - out of wl min/max
# Skipping line ArI at wl=7514.6518 - out of wl min/max
# Skipping line ArII at wl=7589.3151 - out of wl min/max
# Skipping line ArI at wl=7635.106 - out of wl min/max
# Skipping line ArI at wl=7670.0575 - out of wl min/max
# Skipping line ArI at wl=7798.5604 - out of wl min/max
# Skipping line ArI at wl=7868.1946 - out of wl min/max
# Skipping line ArI at wl=7891.075 - out of wl min/max
# Skipping line ArI at wl=7916.442 - out of wl min/max
# Skipping line ArI at wl=7948.1764 - out of wl min/max
# Skipping line ArI at wl=7948.1964 - out of wl min/max
# Skipping line ArI at wl=8006.1567 - out of wl min/max
# Skipping line ArI at wl=8014.7857 - out of wl min/max
# Skipping line ArI at wl=8037.2183 - out of wl min/max
# Skipping line ArI at wl=8046.1169 - out of wl min/max
# Skipping line ArI at wl=8053.3085 - out of wl min/max
# Skipping line ArI at wl=8066.6046 - out of wl min/max
# Skipping line ArI at wl=8103.6931 - out of wl min/max
# Skipping line ArI at wl=8115.311 - out of wl min/max
# Skipping line ArI at wl=8143.505 - out of wl min/max
# Skipping line ArI at wl=8203.4352 - out of wl min/max
# Skipping line ArI at wl=8264.5225 - out of wl min/max
# Skipping line FeI at wl=8327.0526 - out of wl min/max
# Skipping line ArI at wl=8384.724 - out of wl min/max
# Skipping line FeI at wl=8387.77 - out of wl min/max
# Skipping line ArI at wl=8408.2096 - out of wl min/max
# Skipping line ArI at wl=8424.6475 - out of wl min/max
# Skipping line ArI at wl=8490.3065 - out of wl min/max
# Skipping line ArI at wl=8521.4422 - out of wl min/max
# Skipping line ArI at wl=8605.7762 - out of wl min/max
# Skipping line ArI at wl=8620.4602 - out of wl min/max
# Skipping line ArI at wl=8667.9442 - out of wl min/max
# Skipping line FeI at wl=8688.6213 - out of wl min/max
# Skipping line ArI at wl=8761.6862 - out of wl min/max
# Skipping line ArI at wl=8799.0875 - out of wl min/max
# Skipping line ArI at wl=8962.1468 - out of wl min/max
# Skipping line ArII at wl=9008.4636 - out of wl min/max
# Skipping line ArII at wl=9017.5912 - out of wl min/max
# Skipping line ArI at wl=9122.9674 - out of wl min/max
# Skipping line ArI at wl=9194.6385 - out of wl min/max
# Skipping line ArI at wl=9224.4992 - out of wl min/max
# Skipping line ArI at wl=9291.5313 - out of wl min/max
# Skipping line ArI at wl=9354.2198 - out of wl min/max
# Skipping line ArI at wl=9508.4513 - out of wl min/max
# Skipping line ArI at wl=9657.7863 - out of wl min/max
# Skipping line ArI at wl=9657.7863 - out of wl min/max
# Skipping line ArI at wl=9784.5028 - out of wl min/max
# Skipping line ArI at wl=10470.0535 - out of wl min/max

# %% [markdown]
# ## Gilgamesh 2 ---warning!! Halpha might be on/run over a dim sky line

# %%
#RED side SPECTRUM

#define relevant pixel spatial regions
#####################################################
skyaps_red=[(10,20),(300,340)]#[(213,260)(20,26),(310,340)]#[(20,95),(185,230)]#spatial regions above & below target to estimate sky emissions
model_red='linear' #estimating sky line tilt
specaps_red = (100,130)#23,200 target spatial region? area btwn skyaps??
#####################################################

#helps color scale of 2D
vmax = 40
vmin = -10

#subtracts sky lines & stacks target images to extract 1D
target_flux_red, target_unc_red, target_comb_red = pipeline.sky_subtract(targetID, skyaps_red, ds_red, all_side_files_red, atlasfiles_red ,all_side_files_red, flatid, specaps_red, vmax, vmin, model_red)
# Out:
# /Users/dee/Desktop/data_pipeline/reduce_dblspec.py:256: RuntimeWarning: invalid value encountered in sqrt
#   unc = (result/self.header['GAIN'] + self.unc[tsl]**2)**0.5
# 3 target files located
# choose 2D spec for redside
# choose 1D target spec axis limits for redside
